# %% [markdown]
# <a href="https://colab.research.google.com/github/LetyCastineyra/Actividad_3/blob/main/Actividad_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Actividad 3 (Valores Atípicos)
#
# Leticia Castineyra Coutiño A01173881

# %%
#importamos librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#cargar archivo csv desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-46e61127-0de5-41d6-bc88-a9fed494cb7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46e61127-0de5-41d6-bc88-a9fed494cb7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#carga desde un archivo .xlsx sin indice
df = pd.read_csv('Actividad_2.1(ValoresNulos)Sin_Nulos.csv')
df
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           65 non-null     int64
#  1   indice_tiempo                        65 non-null     object
#  2   ventas_precios_corrientes            65 non-null     float64
#  3   ventas_precios_constantes            65 non-null     float64
#  4   ventas_totales_canal_venta           65 non-null     float64
#  5   salon_ventas                         65 non-null     float64
#  6   canales_on_line                      65 non-null     float64
#  7   ventas_totales_medio_pago            65 non-null     float64
#  8   efectivo                             65 non-null     float64
#  9   tarjetas_debito                      65 non-null     float64
#  10  tarjetas_credito                     65 non-null     float64
# ...

# %%
#verificar si ya reemplazamos todos los valores nulos
nulos = df.isnull().sum()
#le decimos que queremos la cantidad de valores nulos en cada columna
nulos
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %% [markdown]
# ##Columna 1

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(10, 6))
plt.boxplot(df['ventas_precios_corrientes'])
plt.title('Outliers de Ventas Precios Corrientes')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Ecuentro cuartiles 0.25 y 0.75
y=df['ventas_precios_corrientes']

percentile25_1=y.quantile(0.25)
percentile75_1=y.quantile(0.75)
iqr = percentile75_1 - percentile25_1

limite_superior_iqr= percentile75_1 + 1.5*iqr
limite_inferior_iqr= percentile25_1 - 1.5*iqr
print('Limite Superior permitido', limite_superior_iqr)
print('Limite Inferior permitido', limite_inferior_iqr)
# Out:
# Limite Superior permitido 192319.35000000003
# Limite Inferior permitido -59178.650000000016

# %%
#Encontramos Outliers
outliers_iqr= df[(y>limite_superior_iqr)|(y<limite_inferior_iqr)]
outliers_iqr
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 42          42    01/07/2020                   211140.7
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 42                    50791.4                 81140696.22   76413721.76
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 42      4726974.457                81140696.22  24935747.29      22143208.63
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                          2502616.619
#
#     electronicos_articulos_hogar        otros
# 42                   6125265.839  5935993.913
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr = df[(y<=limite_superior_iqr)&(y>=limite_inferior_iqr)]
data_clean_iqr
#convertimos los valores atípicos en nulos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#descargar archivo filtrado en csv
data_clean_iqr.to_csv("Columna1.csv")

from google.colab import files
files.download("Columna1.csv")

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(5, 3))
plt.boxplot(data_clean_iqr['ventas_precios_corrientes'])
plt.title('Outliers de Ventas Precios Corrientes')
plt.show() #dibujamos el diagrama

#tenemos un valor aun porque se reacomodaron los indices

# %% [markdown]
# ##Columna 2

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(10, 6))
plt.boxplot(df['salon_ventas'])
plt.title('Outliers Salon Ventas')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Ecuentro cuartiles 0.25 y 0.75
y=df['salon_ventas']

percentile25_2=y.quantile(0.25)
percentile75_2=y.quantile(0.75)
iqr = percentile75_2 - percentile25_2

limite_superior_iqr2= percentile75_2 + 1.5*iqr
limite_inferior_iqr2= percentile25_2 - 1.5*iqr
print('Limite Superior permitido', limite_superior_iqr2)
print('Limite Inferior permitido', limite_inferior_iqr2)
# Out:
# Limite Superior permitido 170440082.58499998
# Limite Inferior permitido -32001350.254999995

# %%
#Encontramos Outliers
outliers_iqr2= df[(y>limite_superior_iqr2)|(y<limite_inferior_iqr2)]
outliers_iqr2
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr2 = df[(y<=limite_superior_iqr2)&(y>=limite_inferior_iqr2)]
data_clean_iqr2
#convertimos los valores atípicos en nulos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#descargar archivo filtrado en csv
data_clean_iqr2.to_csv("Columna2.csv")

from google.colab import files
files.download("Columna2.csv")

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(5, 3))
plt.boxplot(data_clean_iqr2['salon_ventas'])
plt.title('Outliers de Salon ventas')
plt.show() #dibujamos el diagrama

# %% [markdown]
# ##Columna 3

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(10, 6))
plt.boxplot(df['tarjetas_debito'])
plt.title('Outliers de tarjetas de debito')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Ecuentro cuartiles 0.25 y 0.75
y=df['tarjetas_debito']

percentile25_3=y.quantile(0.25)
percentile75_3=y.quantile(0.75)
iqr = percentile75_3 - percentile25_3

limite_superior_iqr3= percentile75_3 + 1.5*iqr
limite_inferior_iqr3= percentile25_3 - 1.5*iqr
print('Limite Superior permitido', limite_superior_iqr3)
print('Limite Inferior permitido', limite_inferior_iqr3)
# Out:
# Limite Superior permitido 51506999.8695
# Limite Inferior permitido -16273799.862499997

# %%
#Encontramos Outliers
outliers_iqr3= df[(y>limite_superior_iqr3)|(y<limite_inferior_iqr3)]
outliers_iqr3
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr3 = df[(y<=limite_superior_iqr3)&(y>=limite_inferior_iqr3)]
data_clean_iqr3
#convertimos los valores atípicos en nulos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#descargar archivo filtrado en csv
data_clean_iqr3.to_csv("Columna3.csv")

from google.colab import files
files.download("Columna3.csv")

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(5, 3))
plt.boxplot(data_clean_iqr2['tarjetas_debito'])
plt.title('Outliers de Tarjetas de Débito')
plt.show() #dibujamos el diagrama

# %% [markdown]
# ##Columna 4

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(10, 6))
plt.boxplot(df['tarjetas_credito'])
plt.title('Outliers de tarjetas de credito')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Ecuentro cuartiles 0.25 y 0.75
y=df['tarjetas_credito']

percentile25_4=y.quantile(0.25)
percentile75_4=y.quantile(0.75)
iqr = percentile75_4 - percentile25_4

limite_superior_iqr4= percentile75_4 + 1.5*iqr
limite_inferior_iqr4= percentile25_4 - 1.5*iqr
print('Limite Superior permitido', limite_superior_iqr4)
print('Limite Inferior permitido', limite_inferior_iqr4)
# Out:
# Limite Superior permitido 63856184.05500001
# Limite Inferior permitido -16515482.225

# %%
#Encontramos Outliers
outliers_iqr4= df[(y>limite_superior_iqr4)|(y<limite_inferior_iqr4)]
outliers_iqr4
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 63  ...  49991675.91  6746166.557  19309461.59  22877841.24
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 63          6510665.781                     1719458.547
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr4 = df[(y<=limite_superior_iqr4)&(y>=limite_inferior_iqr4)]
data_clean_iqr4
#convertimos los valores atípicos en nulos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 58          58    01/11/2021                   141702.0
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#descargar archivo filtrado en csv
data_clean_iqr4.to_csv("Columna4.csv")

from google.colab import files
files.download("Columna4.csv")

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(5, 3))
plt.boxplot(data_clean_iqr4['tarjetas_credito'])
plt.title('Outliers de Tarjetas de Credito')
plt.show() #dibujamos el diagrama

# %% [markdown]
# ##Columna 5

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(10, 6))
plt.boxplot(df['bebidas'])
plt.title('Outliers de bebidas')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Ecuentro cuartiles 0.25 y 0.75
y=df['bebidas']

percentile25_5=y.quantile(0.25)
percentile75_5=y.quantile(0.75)
iqr = percentile75_5 - percentile25_5

limite_superior_iqr5= percentile75_5 + 1.5*iqr
limite_inferior_iqr5= percentile25_5 - 1.5*iqr
print('Limite Superior permitido', limite_superior_iqr5)
print('Limite Inferior permitido', limite_inferior_iqr5)
# Out:
# Limite Superior permitido 22865338.630999997
# Limite Inferior permitido -6791560.384999999

# %%
#Encontramos Outliers
outliers_iqr5= df[(y>limite_superior_iqr5)|(y<limite_inferior_iqr5)]
outliers_iqr5
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr5 = df[(y<=limite_superior_iqr5)&(y>=limite_inferior_iqr5)]
data_clean_iqr5
#convertimos los valores atípicos en nulos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#descargar archivo filtrado en csv
data_clean_iqr5.to_csv("Columna5.csv")

from google.colab import files
files.download("Columna5.csv")

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(5, 3))
plt.boxplot(data_clean_iqr5['bebidas'])
plt.title('Outliers de Bebidas')
plt.show() #dibujamos el diagrama

# %% [markdown]
# ##Columna 6

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(10, 6))
plt.boxplot(df['panaderia'])
plt.title('Outliers de panderia')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Ecuentro cuartiles 0.25 y 0.75
y=df['panaderia']

percentile25_6=y.quantile(0.25)
percentile75_6=y.quantile(0.75)
iqr = percentile75_6 - percentile25_6

limite_superior_iqr6= percentile75_6 + 1.5*iqr
limite_inferior_iqr6= percentile25_6 - 1.5*iqr
print('Limite Superior permitido', limite_superior_iqr6)
print('Limite Inferior permitido', limite_inferior_iqr6)
# Out:
# Limite Superior permitido 5314390.465
# Limite Inferior permitido -928804.111

# %%
#Encontramos Outliers
outliers_iqr6= df[(y>limite_superior_iqr6)|(y<limite_inferior_iqr6)]
outliers_iqr6
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 62                    24612.4                 168982502.3   164321107.3
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59     5.116431e+06                183983151.9  56640033.15      55432191.37
# 62     4.661350e+05                168982502.3  51262080.99      47364363.88
# 63     4.144284e+06                177148082.8  53189998.68      50063972.79
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr6 = df[(y<=limite_superior_iqr6)&(y>=limite_inferior_iqr6)]
data_clean_iqr6
#convertimos los valores atípicos en nulos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 56          56    01/09/2021                   123002.3
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#descargar archivo filtrado en csv
data_clean_iqr6.to_csv("Columna6.csv")

from google.colab import files
files.download("Columna6.csv")

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(5, 3))
plt.boxplot(data_clean_iqr6['panaderia'])
plt.title('Outliers de Panaderia')
plt.show() #dibujamos el diagrama

# %% [markdown]
# ##Columna 7

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(10, 6))
plt.boxplot(df['lacteos'])
plt.title('Outliers de Lacteos')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Ecuentro cuartiles 0.25 y 0.75
y=df['lacteos']

percentile25_7=y.quantile(0.25)
percentile75_7=y.quantile(0.75)
iqr = percentile75_7 - percentile25_7

limite_superior_iqr7= percentile75_7 + 1.5*iqr
limite_inferior_iqr7= percentile25_7 - 1.5*iqr
print('Limite Superior permitido', limite_superior_iqr7)
print('Limite Inferior permitido', limite_inferior_iqr7)
# Out:
# Limite Superior permitido 19940661.0455
# Limite Inferior permitido -5569362.3025

# %%
#Encontramos Outliers
outliers_iqr7= df[(y>limite_superior_iqr7)|(y<limite_inferior_iqr7)]
outliers_iqr7
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64           6314109.47                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                    23578638.71                          5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                   12039595.55  12349980.06
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr7 = df[(y<=limite_superior_iqr7)&(y>=limite_inferior_iqr7)]
data_clean_iqr7
#convertimos los valores atípicos en nulos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#descargar archivo filtrado en csv
data_clean_iqr7.to_csv("Columna7.csv")

from google.colab import files
files.download("Columna7.csv")

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(5, 3))
plt.boxplot(data_clean_iqr6['lacteos'])
plt.title('Outliers de Lacteos')
plt.show() #dibujamos el diagrama

# %% [markdown]
# ##Columna 8

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(10, 6))
plt.boxplot(df['electronicos_articulos_hogar'])
plt.title('Outliers de Electronicos de articulos de hogar')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Ecuentro cuartiles 0.25 y 0.75
y=df['electronicos_articulos_hogar']

percentile25_8=y.quantile(0.25)
percentile75_8=y.quantile(0.75)
iqr = percentile75_8 - percentile25_8

limite_superior_iqr8= percentile75_8 + 1.5*iqr
limite_inferior_iqr8= percentile25_8 - 1.5*iqr
print('Limite Superior permitido', limite_superior_iqr8)
print('Limite Inferior permitido', limite_inferior_iqr8)
# Out:
# Limite Superior permitido 11851594.895499999
# Limite Inferior permitido -3640353.060499999

# %%
#Encontramos Outliers
outliers_iqr8= df[(y>limite_superior_iqr8)|(y<limite_inferior_iqr8)]
outliers_iqr8
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 58          58    01/11/2021                   141702.0
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 58                    25026.6                 141701960.7   135950778.8
# 59                    31595.7                 183983151.9   178866721.2
# 60                    45463.4                 154517094.2   149697614.6
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 58      5751181.809                141701960.7  43762928.15      39925207.45
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# 60      4819479.554                154517094.2  46962602.22      46053650.13
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr8 = df[(y<=limite_superior_iqr8)&(y>=limite_inferior_iqr8)]
data_clean_iqr8
#convertimos los valores atípicos en nulos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 56          56    01/09/2021                   123002.3
# 57          57    01/10/2021                   140487.5
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#descargar archivo filtrado en csv
data_clean_iqr8.to_csv("Columna8.csv")

from google.colab import files
files.download("Columna8.csv")

# %%
#Obtenemos datos limpios
data_clean_iqr8 = df[(y<=limite_superior_iqr8)&(y>=limite_inferior_iqr8)]
data_clean_iqr8
#convertimos los valores atípicos en nulos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 56          56    01/09/2021                   123002.3
# 57          57    01/10/2021                   140487.5
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(5, 3))
plt.boxplot(data_clean_iqr8['electronicos_articulos_hogar'])
plt.title('Outliers de Electronicos articulos de hogar')
plt.show() #dibujamos el diagrama

# %% [markdown]
# ##Columna 9

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(10, 6))
plt.boxplot(df['ventas_precios_constantes'])
plt.title('Outliers de Ventas Precios Constantes')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Ecuentro cuartiles 0.25 y 0.75
y=df['ventas_precios_constantes']

percentile25_9=y.quantile(0.25)
percentile75_9=y.quantile(0.75)
iqr = percentile75_9 - percentile25_9

limite_superior_iqr9= percentile75_9 + 1.5*iqr
limite_inferior_iqr9= percentile25_9 - 1.5*iqr
print('Limite Superior permitido', limite_superior_iqr9)
print('Limite Inferior permitido', limite_inferior_iqr9)
# Out:
# Limite Superior permitido 31938.75
# Limite Inferior permitido 18759.949999999997

# %%
#Encontramos Outliers
outliers_iqr9= df[(y>limite_superior_iqr9)|(y<limite_inferior_iqr9)]
outliers_iqr9
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 11          11    01/12/2017                    40766.3
# 42          42    01/07/2020                   211140.7
# 60          60    01/01/2022                   154517.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 11                    34084.5                4.076632e+07  4.032029e+07
# 42                    50791.4                8.114070e+07  7.641372e+07
# 60                    45463.4                1.545171e+08  1.496976e+08
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 11     4.460368e+05               4.076632e+07  13710305.37      11070098.74
# 42     4.726974e+06               8.114070e+07  24935747.29      22143208.63
# 60     4.819480e+06               1.545171e+08  46962602.22      46053650.13
#
#     ...       almacen    panaderia       lacteos        carnes  \
# 11  ...  9.667850e+06  1346130.813  3.684165e+06  3.674954e+06
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr9 = df[(y<=limite_superior_iqr9)&(y>=limite_inferior_iqr9)]
data_clean_iqr9
#convertimos los valores atípicos en nulos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#descargar archivo filtrado en csv
data_clean_iqr9.to_csv("Columna9.csv")

from google.colab import files
files.download("Columna9.csv")

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(5, 3))
plt.boxplot(data_clean_iqr9['ventas_precios_constantes'])
plt.title('Outliers de Ventas Precios Constantes ')
plt.show() #dibujamos el diagrama

# %% [markdown]
# ##Columna 10

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(10, 6))
plt.boxplot(df['indumentaria_calzado_textiles_hogar'])
plt.title('Outliers de Ventas Precios Corrientes')
plt.show() #dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Ecuentro cuartiles 0.25 y 0.75
y=df['indumentaria_calzado_textiles_hogar']

percentile25_10=y.quantile(0.25)
percentile75_10=y.quantile(0.75)
iqr = percentile75_10 - percentile25_10

limite_superior_iqr10= percentile75_10 + 1.5*iqr
limite_inferior_iqr10= percentile25_10 - 1.5*iqr
print('Limite Superior permitido', limite_superior_iqr10)
print('Limite Inferior permitido', limite_inferior_iqr10)
# Out:
# Limite Superior permitido 4070013.5714000002
# Limite Inferior permitido -898722.7150000001

# %%
#Encontramos Outliers
outliers_iqr10= df[(y>limite_superior_iqr10)|(y<limite_inferior_iqr10)]
outliers_iqr10
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 63                    24140.5                 177148082.8   173003799.1
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# 63      4144283.743                177148082.8  53189998.68      50063972.79
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr10 = df[(y<=limite_superior_iqr10)&(y>=limite_inferior_iqr10)]
data_clean_iqr10
#convertimos los valores atípicos en nulos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#descargar archivo filtrado en csv
data_clean_iqr10.to_csv("Columna10.csv")

from google.colab import files
files.download("Columna10.csv")

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize=(5, 3))
plt.boxplot(data_clean_iqr9['indumentaria_calzado_textiles_hogar'])
plt.title('Outliers de Indumentaria Calzado y Textiles del hogar ')
plt.show() #dibujamos el diagrama
